# %% [markdown]
# #### Problem Statement :-
#     Predict the price of the Uber ride from a given pickup point to the agreed drop-off location. Perform following tasks:           1. Pre-process the dataset.                                                                                                     2. Identify outliers.                                                                                                           3. Check the correlation.
#     4. Implement linear regression and random forest regression models.
#     5. Evaluate the models and compare their respective scores like R2, RMSE, etc.
#   Dataset link: https://www.kaggle.com/datasets/yasserh/uber-fares-dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import calendar
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error,accuracy_score

# %% [markdown]
# ### Pre-processing the dataset

# %%
df = pd.read_csv('uber.csv')
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# 25%           -73.991407         40.733823         1.000000
# 50%           -73.980093         40.753042         1.000000
# 75%           -73.963658         40.768001         2.000000
# max          1153.572603        872.697628       208.000000

# %%
df.rename(columns={'Unnamed: 0':'id'}, inplace=True)               # renaming unnamed column
df["pickup_datetime"] = pd.to_datetime(df['pickup_datetime'])      # changing datatype to datetime
df['day']     = df['pickup_datetime'].apply(lambda x:x.day)
df['hour']    = df['pickup_datetime'].apply(lambda x:x.hour)
df['weekday'] = df['pickup_datetime'].apply(lambda x:calendar.day_name[x.weekday()])
df['month']   = df['pickup_datetime'].apply(lambda x:x.month)
df['year']    = df['pickup_datetime'].apply(lambda x:x.year)
df.head()
# Out:
#          id                            key  fare_amount  \
# 0  24238194    2015-05-07 19:52:06.0000003          7.5
# 1  27835199    2009-07-17 20:04:56.0000002          7.7
# 2  44984355   2009-08-24 21:45:00.00000061         12.9
# 3  25894730    2009-06-26 08:22:21.0000001          5.3
# 4  17610152  2014-08-28 17:47:00.000000188         16.0
#
#             pickup_datetime  pickup_longitude  pickup_latitude  \
# 0 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2 2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4 2014-08-28 17:47:00+00:00        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  day  hour   weekday  \
# 0         -73.999512         40.723217                1    7    19  Thursday
# 1         -73.994710         40.750325                1   17    20    Friday
# 2         -73.962565         40.772647                1   24    21    Monday
# 3         -73.965316         40.803349                3   26     8    Friday
# 4         -73.973082         40.761247                5   28    17  Thursday
#
#    month  year
# 0      5  2015
# 1      7  2009
# 2      8  2009
# 3      6  2009
# 4      8  2014

# %%
df = df[df['fare_amount']>0]                     # fare_amount can't be negative
df = df[df['passenger_count']<=8]                # considering max passenger_count = 8
df.drop(["id", "key", "pickup_datetime"], axis=1, inplace=True)
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  day  hour   weekday  month  year
# 0         40.723217                1    7    19  Thursday      5  2015
# 1         40.750325                1   17    20    Friday      7  2009
# 2         40.772647                1   24    21    Monday      8  2009
# 3         40.803349                3   26     8    Friday      6  2009
# 4         40.761247                5   28    17  Thursday      8  2014

# %%
df.weekday = df.weekday.map({'Sunday':0,'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5,'Saturday':6})
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  day  hour  weekday  month  year
# 0         40.723217                1    7    19        4      5  2015
# 1         40.750325                1   17    20        5      7  2009
# 2         40.772647                1   24    21        1      8  2009
# 3         40.803349                3   26     8        5      6  2009
# 4         40.761247                5   28    17        4      8  2014

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199977 entries, 0 to 199999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        199977 non-null  float64
#  1   pickup_longitude   199977 non-null  float64
#  2   pickup_latitude    199977 non-null  float64
#  3   dropoff_longitude  199976 non-null  float64
#  4   dropoff_latitude   199976 non-null  float64
#  5   passenger_count    199977 non-null  int64
#  6   day                199977 non-null  int64
#  7   hour               199977 non-null  int64
#  8   weekday            199977 non-null  int64
#  9   month              199977 non-null  int64
#  10  year               199977 non-null  int64
# dtypes: float64(5), int64(6)
# memory usage: 18.3 MB

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  199977.000000     199977.000000    199977.000000      199976.000000
# mean       11.362648        -72.527844        39.935995         -72.526236
# std         9.897104         11.437285         7.720462          13.115146
# min         0.010000      -1340.648410       -74.015515       -3356.666300
# 25%         6.000000        -73.992065        40.734795         -73.991407
# 50%         8.500000        -73.981823        40.752592         -73.980093
# 75%        12.500000        -73.967155        40.767158         -73.963660
# max       499.000000         57.418457      1644.421482        1153.572603
#
#        dropoff_latitude  passenger_count            day           hour  \
# count     199976.000000    199977.000000  199977.000000  199977.000000
# mean          39.924406         1.683449      15.704941      13.491427
# std            6.793455         1.306934       8.687517       6.515413
# min         -881.985513         0.000000       1.000000       0.000000
# 25%           40.733825         1.000000       8.000000       9.000000
# 50%           40.753042         1.000000      16.000000      14.000000
# 75%           40.768001         2.000000      23.000000      19.000000
# max          872.697628         6.000000      31.000000      23.000000
#
#              weekday          month           year
# count  199977.000000  199977.000000  199977.000000
# mean        3.122989       6.282117    2011.742315
# std         1.987301       3.438909       1.856277
# min         0.000000       1.000000    2009.000000
# 25%         1.000000       3.000000    2010.000000
# 50%         3.000000       6.000000    2012.000000
# 75%         5.000000       9.000000    2013.000000
# max         6.000000      12.000000    2015.000000

# %%
#dealing with missing values
df.isna().sum()
# Out:
# fare_amount          0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# day                  0
# hour                 0
# weekday              0
# month                0
# year                 0
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# fare_amount          0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# day                  0
# hour                 0
# weekday              0
# month                0
# year                 0
# dtype: int64

# %% [markdown]
# ### Outlier Detection

# %%
sns.boxplot(x='fare_amount', data=df)
# Out:
# <AxesSubplot:xlabel='fare_amount'>

# %%
Q1 = np.percentile(df['fare_amount'], 25, interpolation='midpoint')
Q3 = np.percentile(df['fare_amount'], 75, interpolation='midpoint')
IQR = Q3 - Q1

upper = Q3 + 1.5 * IQR
lower = Q1 - 1.5 * IQR

print("Upper = ", upper)
print("Lower = ", lower)
# Out:
# Upper =  22.25
# Lower =  -3.75

# %%
print("Outliers")
df[(df['fare_amount']<lower) | (df['fare_amount']>upper)][{'fare_amount', 'day', 'month', 'year'}]
# Out:
# Outliers
# C:\Users\karan\AppData\Local\Temp\ipykernel_3416\1199643809.py:2: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[(df['fare_amount']<lower) | (df['fare_amount']>upper)][{'fare_amount', 'day', 'month', 'year'}]
#         year  month  fare_amount  day
# 6       2014     10        24.50   12
# 30      2011      5        25.70   21
# 34      2014      6        39.50    4
# 39      2014      2        29.00   13
# 48      2013      1        56.80    3
# ...      ...    ...          ...  ...
# 199976  2011     10        49.70   18
# 199977  2012     11        43.50   20
# 199982  2014      8        57.33    6
# 199985  2015      4        24.00   18
# 199997  2009      6        30.90   29
#
# [17155 rows x 4 columns]

# %%
print("old shape", df.shape)
df = df[(df['fare_amount']>=lower) & (df['fare_amount']<=upper)]
print("new shape", df.shape)
# Out:
# old shape (199976, 11)
# new shape (182821, 11)

# %%
sns.boxplot(x='fare_amount', data=df)
# Out:
# <AxesSubplot:xlabel='fare_amount'>

# %% [markdown]
# ### correlation

# %%
corr_matrix=round(df.corr(),2)
corr_matrix
# Out:
#                    fare_amount  pickup_longitude  pickup_latitude  \
# fare_amount               1.00              0.00             0.00
# pickup_longitude          0.00              1.00            -0.81
# pickup_latitude           0.00             -0.81             1.00
# dropoff_longitude        -0.00              0.84            -0.77
# dropoff_latitude          0.00             -0.85             0.68
# passenger_count           0.01             -0.00            -0.00
# day                       0.01              0.00            -0.01
# hour                     -0.01              0.00            -0.00
# weekday                   0.02             -0.00             0.00
# month                     0.03             -0.00             0.00
# year                      0.14              0.01            -0.01
#
#                    dropoff_longitude  dropoff_latitude  passenger_count   day  \
# fare_amount                    -0.00              0.00             0.01  0.01
# pickup_longitude                0.84             -0.85            -0.00  0.00
# pickup_latitude                -0.77              0.68            -0.00 -0.01
# dropoff_longitude               1.00             -0.91             0.00  0.00
# dropoff_latitude               -0.91              1.00            -0.00 -0.01
# passenger_count                 0.00             -0.00             1.00  0.00
# day                             0.00             -0.01             0.00  1.00
# hour                            0.00             -0.00             0.02  0.01
# weekday                        -0.00             -0.00             0.01  0.01
# month                          -0.00              0.00             0.01 -0.02
# year                            0.01             -0.01             0.00 -0.01
#
#                    hour  weekday  month  year
# fare_amount       -0.01     0.02   0.03  0.14
# pickup_longitude   0.00    -0.00  -0.00  0.01
# pickup_latitude   -0.00     0.00   0.00 -0.01
# dropoff_longitude  0.00    -0.00  -0.00  0.01
# dropoff_latitude  -0.00    -0.00   0.00 -0.01
# passenger_count    0.02     0.01   0.01  0.00
# day                0.01     0.01  -0.02 -0.01
# hour               1.00     0.03  -0.00  0.00
# weekday            0.03     1.00  -0.00 -0.00
# month             -0.00    -0.00   1.00 -0.12
# year               0.00    -0.00  -0.12  1.00

# %%
plt.figure(figsize=(20,15))
sns.heatmap(corr_matrix,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Linear Regression

# %%
x = df.drop("fare_amount", axis=1)
y = df['fare_amount']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 1)

# %%
ss = preprocessing.StandardScaler()
x_train =  ss.fit_transform(x_train)
x_test = ss.transform(x_test)

# %%
y_train = np.asarray(y_train)
y_test = np.asarray(y_test)

# %%
lrmodel = LinearRegression()
lrmodel.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lrmodel.predict(x_test)
df_preds = pd.DataFrame({'Actual: ': y_test, 'Predicted: ': y_pred})
df_preds.head(10)
# Out:
#    Actual:   Predicted:
# 0       9.5     9.586672
# 1       8.5     8.976306
# 2       6.0     9.649910
# 3       9.3     8.938668
# 4       8.1     8.724896
# 5       7.7     8.296916
# 6       7.3     9.116215
# 7      17.3     8.305642
# 8       9.7     8.734735
# 9       9.0     9.738842

# %%
print("Regression Coefficients : ", lrmodel.coef_)
print("Intercept : ", lrmodel.intercept_)
# Out:
# Regression Coefficients :  [ 0.04681514  0.0342183  -0.02682751 -0.0063804   0.04924538  0.03211746
#  -0.06186189  0.09037254  0.17077173  0.58896141]
# Intercept :  8.931780234657069

# %%
print("Linear regression Model :")
print("MSE:", mean_squared_error(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print('R2 Score:',metrics.r2_score(y_test, y_pred))
# Out:
# Linear regression Model :
# MSE: 16.933564374924288
# MAE: 3.2618394062974816
# RMSE: 4.115041236114687
# R2 Score: 0.019181175931181516

# %% [markdown]
# ### Random Forest Regression

# %%
rfrmodel = RandomForestRegressor(n_estimators=10, random_state=1)

# %%
rfrmodel.fit(x_train,y_train)
rfrmodel_pred= rfrmodel.predict(x_test)

# %%
rf_preds = pd.DataFrame({'Actual: ': y_test, 'Predicted: ': rfrmodel_pred})
rf_preds.head(10)
# Out:
#    Actual:   Predicted:
# 0       9.5        8.250
# 1       8.5        5.100
# 2       6.0        9.100
# 3       9.3        8.465
# 4       8.1        9.340
# 5       7.7        7.400
# 6       7.3        8.920
# 7      17.3       13.730
# 8       9.7       11.670
# 9       9.0        7.900

# %%
print("Random forest regression model : ")
print("MSE:", mean_squared_error(y_test, rfrmodel_pred))
print("MAE:", mean_absolute_error(y_test, rfrmodel_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, rfrmodel_pred)))
print('R2 Score:',metrics.r2_score(y_test, rfrmodel_pred))
# Out:
# Random forest regression model :
# MSE: 4.7524971273591925
# MAE: 1.5045106431469075
# RMSE: 2.1800222768034256
# R2 Score: 0.7247278517008784
